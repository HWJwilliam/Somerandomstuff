# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:1eab7c8c-409f-46b1-9de3-0c3b31a2d99d.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:331a1f5c-a325-4023-89b3-5d8710a648a1.png)

# %% [markdown]
# Objectives:
# *List popular languages for Data Science
# *Use R and related libraries
# *Use Markdown and Code editor for Jupyter Notebooks
# ![10-objectives.png](attachment:6a15337c-c7b8-4a2f-bd4e-90cd1c8b66ce.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R
# ![4-dslanguages.png](attachment:65d3808d-079d-4a09-bca7-479ada110918.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# ![5-dslibraries.png](attachment:33884e36-4e2f-4a77-b0cf-690bcf79299a.png)

# %% [markdown]
# | Data Science Tools |
# | ------ |
# | MySQL |
# | MongoDB |
# | Cassandra |
# ![6-dstools.png](attachment:54c0e982-0149-4463-94ce-2c76d52baeb3.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# ![7-introarithmetic.png](attachment:29bcf1d2-12ed-47d9-b6bc-0a318304975f.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:dadb60f1-d07b-4a09-ac85-985ccecb61e8.png)

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:0f5e799c-9148-4ad7-8d79-9cdb42c4c7b9.png)

# %% [markdown]
# ## Author
# Wenjun He
# ![11-authordetails.png](attachment:ad5c90a7-9044-4761-8ee3-6902245e1cb6.png)
